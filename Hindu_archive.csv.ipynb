# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
driver= webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.thehindu.com/archive/web/2020/11/'
driver.get(url)

# %%
#Dates Urls
date_urls = []
date = driver.find_elements_by_xpath('//a[@class="ui-state-default"]')
for i in date:
    date_urls.append(i.get_attribute('href'))

date_urls
# Out:
# ['https://www.thehindu.com/archive/web/2020/11/01/',
#  'https://www.thehindu.com/archive/web/2020/11/02/',
#  'https://www.thehindu.com/archive/web/2020/11/03/',
#  'https://www.thehindu.com/archive/web/2020/11/04/',
#  'https://www.thehindu.com/archive/web/2020/11/05/',
#  'https://www.thehindu.com/archive/web/2020/11/06/',
#  'https://www.thehindu.com/archive/web/2020/11/07/',
#  'https://www.thehindu.com/archive/web/2020/11/08/',
#  'https://www.thehindu.com/archive/web/2020/11/09/',
#  'https://www.thehindu.com/archive/web/2020/11/10/',
#  'https://www.thehindu.com/archive/web/2020/11/11/',
#  'https://www.thehindu.com/archive/web/2020/11/12/',
#  'https://www.thehindu.com/archive/web/2020/11/13/',
#  'https://www.thehindu.com/archive/web/2020/11/14/',
#  'https://www.thehindu.com/archive/web/2020/11/15/',
#  'https://www.thehindu.com/archive/web/2020/11/16/',
#  'https://www.thehindu.com/archive/web/2020/11/17/',
#  'https://www.thehindu.com/archive/web/2020/11/18/',
# ...

# %%
## news URLs
news_url = []
for date in date_urls[0:30]:  # scrape news url from 30 dates
    driver.get(date)
    news = driver.find_elements_by_xpath(("//ul[@class='archive-list']/li/a"))
    for i in news:
        news_url.append(i.get_attribute("href"))
news_url
# Out:
# ['https://www.thehindu.com/news/cities/bangalore/with-schools-shut-special-children-cut-off-from-social-skills-training-and-therapy/article32993173.ece',
#  'https://www.thehindu.com/news/cities/bangalore/rejig-of-cubbon-park-and-shivajinagar-bus-station-begins/article32992875.ece',
#  'https://www.thehindu.com/news/cities/bangalore/bus-ploughs-into-restaurant-four-pedestrians-injured/article32995486.ece',
#  'https://www.thehindu.com/news/cities/bangalore/dj-halli-case-former-mayor-yet-to-be-traced/article32992951.ece',
#  'https://www.thehindu.com/news/cities/bangalore/karnatakas-daily-tpr-falls-to-296/article32993394.ece',
#  'https://www.thehindu.com/news/cities/bangalore/only-40-councillors-have-returned-e-tablets/article32992816.ece',
#  'https://www.thehindu.com/news/cities/bangalore/aam-aadmi-clinic-in-shantinagar/article32992797.ece',
#  'https://www.thehindu.com/news/cities/chennai/tasmac-shops-to-stay-open-till-10-pm/article32994386.ece',
# ...

# %%
# length of news URL's
len(news_url)
# Out:
# 10973

# %%
# Headlines for all 30 dates extracted
headline = []
for url in news_url[0:1500]:
    driver.get(url)
    head = driver.find_elements_by_xpath(('//h1[@class="title"]'))
    for i in head:
        headline.append(i.text)
        
headline
# Out:
# ['With schools shut, special children cut off from social skills training and therapy',
#  'Rejig of Cubbon Park and Shivajinagar bus station begins',
#  'Bus ploughs into restaurant, four pedestrians injured',
#  'D.J. Halli case: Former mayor yet to be traced',
#  'Karnataka’s COVID-19 daily TPR falls to 2.96%',
#  'Only 40 councillors have returned e-tablets',
#  '‘Aam Aadmi Clinic’ in Shantinagar',
#  'Tasmac shops to stay open till 10 p.m.',
#  'Awareness on abdomen stones',
#  '‘Unauthorised persons using advocate stickers’',
#  'Do not fall prey to imposters: city police',
#  'EPFO gives pension payment orders to retired employees',
#  'IAS Officer Sagayam applies for VRS',
#  'No funds to pay monthly pensions: Madras University',
#  'Coronavirus | ‘50% residents don’t wear masks’: Chennai Corporation Commissioner',
#  '‘Observation, application helps in animation and design’',
#  'Two held for transporting gutkha products',
#  'National Unity Day observed by city police',
# ...

# %%
#Description for first 1000 news extracted

description = []
for news in news_url[0:1000]:
    driver.get(news)
    des = driver.find_elements_by_xpath('/html/body/div[2]/div[2]/div/div/div/section/div/div/div/div[3]/div[3]')
    for i in des:
        description.append(i.text)
description
# Out:
# ['Jacklene S. is a single parent of an 11-year-old. While the outbreak of COVID-19 turned life upside down for most people, for her, as the mother of a special child, it meant taking some desperate measures.\nHer son, Joshua Vivan, is a non-verbal autistic child. Ms. Jacklene used to work as a teacher and drop him off at a special school before going to work, and pick him up later. But the pandemic meant that she remained out of work and unpaid as there was no provision for online classes in her school.\n“It became very difficult for me as I couldn’t manage him at home. He became very aggressive, tearing clothes and hitting me. I could not control him as he was not ready to be at home,” she said.\nWith money running out, she took up a marketing job. With no external support, she started changing her child’s routine to sleep during the day, so she could step out for work, and return in time for his online classes.\n“The special school gave him a tab and started an hour’s class in the 
# ...

# %%
# Dates for first 1000 news extracted
dates = []

for news in news_url[0:1000]:
    driver.get(news)
    date = driver.find_elements_by_xpath("//span[@class='blue-color ksl-time-stamp']/none")
    for i in date:
        dates.append(i.text)  
    
dates
# Out:
# ['NOVEMBER 01, 2020 08:59 IST',
#  '',
#  'NOVEMBER 01, 2020 08:58 IST',
#  '',
#  'NOVEMBER 01, 2020 07:22 IST',
#  '',
#  'NOVEMBER 01, 2020 07:08 IST',
#  '',
#  'NOVEMBER 01, 2020 06:47 IST',
#  '',
#  'NOVEMBER 01, 2020 06:21 IST',
#  '',
#  'NOVEMBER 01, 2020 01:29 IST',
#  '',
#  'NOVEMBER 01, 2020 02:25 IST',
#  '',
#  'NOVEMBER 01, 2020 02:24 IST',
#  '',
#  'NOVEMBER 01, 2020 02:21 IST',
#  '',
#  'NOVEMBER 01, 2020 02:19 IST',
#  '',
#  'NOVEMBER 01, 2020 02:12 IST',
#  '',
#  'NOVEMBER 01, 2020 02:09 IST',
#  '',
#  'NOVEMBER 01, 2020 02:03 IST',
#  '',
#  'NOVEMBER 01, 2020 02:00 IST',
#  '',
#  'NOVEMBER 01, 2020 01:58 IST',
#  '',
#  'NOVEMBER 01, 2020 01:30 IST',
#  '',
#  'NOVEMBER 01, 2020 01:28 IST',
#  '',
#  'NOVEMBER 01, 2020 01:25 IST',
#  '',
#  'NOVEMBER 01, 2020 21:54 IST',
#  '',
#  'NOVEMBER 01, 2020 04:53 IST',
#  '',
#  'NOVEMBER 01, 2020 01:26 IST',
#  '',
#  'NOVEMBER 01, 2020 01:12 IST',
#  '',
#  'NOVEMBER 01, 2020 01:02 IST',
#  '',
# ...

# %%
# Author for first 1000 news extracted

Author = []

for news in news_url[0:1000]:
    driver.get(news)
    Auth = driver.find_elements_by_xpath("//a[@class='auth-nm lnk']")
    for i in Auth:
        Author.append(i.text)  
    
Author
# Out:
# ['K.C. Deepika',
#  'Jenny Varghese',
#  'Venugopal Menon',
#  'R. Ananda Kumar',
#  'Shikha Dubey',
#  'Kriti Soni',
#  'Aakash Bajpai',
#  'Shobha Anand',
#  'Lakshmi Mitter',
#  'Ashok Balakrishna',
#  'Sports Bureau',
#  'The Hindu Net Desk',
#  'The Hindu Net Desk',
#  'Amarnath Tewary',
#  'Amarnath Tewary',
#  'Varghese K. George',
#  'Sriram Lakshman',
#  'Suhasini Haidar',
#  'Meera Srinivasan',
#  'Srinivasan Ramani',
#  'Rajesh B. Nair',
#  'G. PrasadSpecial Correspondent',
#  'C. Jaisankar',
#  'Dinakar Peri',
#  'Sidharth Yadav',
#  'Vijaita Singh',
#  'Jagriti Chandra',
#  'Varghese K. George',
#  'Vijaita Singh',
#  'T. Appala Naidu',
#  'Rajulapudi Srinivas',
#  'Rajulapudi Srinivas',
#  'V. Raghavendra',
#  'Tharun Boda',
#  'Sumit Bhattacharjee',
#  'Ramesh Susarla',
#  'A.D. Rangarajan',
#  'T. Appala Naidu',
#  'T. Appala Naidu',
#  'Sumit Bhattacharjee',
#  'K. Umashanker',
#  'Rajulapudi Srinivas',
#  'Kumar Buradikatti',
#  'Rishikesh Bahadur Desai',
# ...

# %%
# State categories for first 1000 dates extracted

Category = []

for news in news_url[0:1000]:
    driver.get(news)
    Auth = driver.find_elements_by_xpath("//a[@class='section-name']")
    for i in Auth:
        Category.append(i.text)  
    
Category
# Out:
# ['BENGALURU',
#  'BENGALURU',
#  'BENGALURU',
#  'BENGALURU',
#  'BENGALURU',
#  'BENGALURU',
#  'BENGALURU',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'LETTERS',
#  'OTHER SPORTS',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'OPEN PAGE',
#  'RACES',
#  'TENNIS',
#  'TENNIS',
#  'TENNIS',
#  'MUMBAI',
#  'MUMBAI',
#  'NEWS',
#  'NEWS',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'INTERNATIONAL',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'BIHAR',
#  'CHILDREN',
#  'PUDUCHERRY',
#  'PUDUCHERRY',
#  'PUDUCHERRY',
#  'PUDUCHERRY',
#  'PUDUCHERRY',
#  'PUDUCHERRY',
# ...

# %%
len(dates)
# Out:
# 1996

# %%
len(Author)
# Out:
# 307

# %%
len(Category)
# Out:
# 993

# %%
len(headline)
# Out:
# 1490

# %%
len(description)
# Out:
# 958

# %%
df=pd.DataFrame({"Date of upload":dates,"Author name":Author,"Vertical/Topic":Category,
                 "Headline":headline[:500],"Description":description})
df
